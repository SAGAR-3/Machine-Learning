# %% [markdown]
# # Percentiles

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.5, 10000)

plt.hist(vals, 50)
plt.show()

# %%
np.percentile(vals, 50)
# Out:
# -0.001311288245866721

# %%
np.percentile(vals, 90)
# Out:
# 0.6297555287690307

# %%
np.percentile(vals, 20)
# Out:
# -0.42486098108450426

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters when creating the test data. What effect does it have on the percentiles?

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(2, 1, 10000)

plt.hist(vals, 50)
plt.show()

# %%
np.percentile(vals, 50) #median
# Out:
# 1.997439755122344

# %%
np.percentile(vals, 80)
# Out:
# 2.84202743436505

# %%
np.percentile(vals, 10)
# Out:
# 0.7380825324126286
