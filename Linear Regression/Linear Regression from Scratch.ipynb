# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
training_set = pd.read_csv('Salary_Data.csv')

# %%
training_set.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
x_train = training_set['YearsExperience'].values

# %%
y_train = training_set['Salary'].values

# %%
plt.scatter(x_train, y_train)
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# Implementation Plan
#
# 1. Cost Function :  Using Mean Square Error (MSE)
# 2. Gradient Function : To Compute the derivatives of the cost function
# 3. Gradient Descent Function : To update the parameters (w,b) over a specified number of iterations

# %%
def cost_function(x, y, w, b):
    m = len(x)
    cost_sum = 0
    
    for i in range(z):
        f = w * x[i] + b
        cost = (f - y[i]) ** 2
        cost_sum += cost
        
    total_cost = (1/(2*z)) * cost_sum 
    return total_cost

# %%
def gradient_function(x, y, w, b):
    m = len(x)
    
    dc_dw = 0
    dc_db = 0
    
    for i in range(m):
        f = w * w[i] + b
        
        dc_dw += (f - y[i]) * x[i]
        dc_db += (f - y[i])
        
    dc_dw = (1/m) * dc_dw
    dc_db = (1/m) * dc_db

# %%
def gradient_descent_function(x, y, learning_rate, iterations):
    w = 0
    b = 0
    
    for i in range(iterations):
        dc_dw, dc_db = gradient_function(x, y, w, b)
        
        w = w - alpha * dc_dw
        b = b - alpha * dc_db
        
        print(f"Iteration {i}: Cost {cost_function(x, y, w, b)}")
        
    return w, b

# %%
learning_rate = 0.01
iterations = 10000

final_w, final_b = gradient_descent(x_train, y_train, learning_rate, iterations)

print(f"w: {final_w:.4f}, b: {final_b:.4f}")
# Out:
# w: 9449.9623, b: 25792.2002

# %%
plt.scatter(x_train, y_train, label='Data Points')

x_vals = np.linspace(min(x_train), max(x_train), 100)
y_vals = final_w * x_vals + final_b
plt.plot(x_vals, y_vals, color='red', label='Regression Line')

plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.legend()
plt.show()
